# %%
import pandas as pd
import seaborn as sns

# %%
df =pd.read_csv('car_data.csv')

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
print(df['seller_type'].unique())
print(df['transmission'].unique())
print(df['owner'].unique())
# Out:
# ['Individual' 'Dealer' 'Trustmark Dealer']
# ['Manual' 'Automatic']
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %%
##check missing and null values
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
final_dataset=df[['year', 'selling_price', 'km_driven', 'fuel', 'seller_type','transmission', 'owner']]

# %%
final_dataset.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %%
final_dataset['Current_year']=2022

# %%
final_dataset['Number of years']=final_dataset['Current_year']-final_dataset['year']

# %%
final_dataset.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner  Current_year  Number of years
# 0   First Owner          2022               15
# 1   First Owner          2022               15
# 2   First Owner          2022               10
# 3   First Owner          2022                5
# 4  Second Owner          2022                8

# %%
##delete the column 'year' from the dataset
final_dataset.drop(['year'],axis=1,inplace=True)

# %%
final_dataset.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0          60000      70000  Petrol  Individual       Manual   First Owner
# 1         135000      50000  Petrol  Individual       Manual   First Owner
# 2         600000     100000  Diesel  Individual       Manual   First Owner
# 3         250000      46000  Petrol  Individual       Manual   First Owner
# 4         450000     141000  Diesel  Individual       Manual  Second Owner
#
#    Current_year  Number of years
# 0          2022               15
# 1          2022               15
# 2          2022               10
# 3          2022                5
# 4          2022                8

# %%
final_dataset=pd.get_dummies(final_dataset, drop_first=True)

# %%
final_dataset.head()
# Out:
#    selling_price  km_driven  Current_year  Number of years  fuel_Diesel  \
# 0          60000      70000          2022               15            0
# 1         135000      50000          2022               15            0
# 2         600000     100000          2022               10            1
# 3         250000      46000          2022                5            0
# 4         450000     141000          2022                8            1
#
#    fuel_Electric  fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0              0         0            1                       1
# 1              0         0            1                       1
# 2              0         0            0                       1
# 3              0         0            1                       1
# 4              0         0            0                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  \
# 0                             0                    1
# 1                             0                    1
# 2                             0                    1
# 3                             0                    1
# 4                             0                    1
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                           0                   0                     0
# 1                           0                   0                     0
# 2                           0                   0                     0
# 3                           0                   0                     0
# 4                           0                   1                     0
#
#    owner_Third Owner
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
final_dataset.corr()
# Out:
#                               selling_price  km_driven  Current_year  \
# selling_price                      1.000000  -0.192289           NaN
# km_driven                         -0.192289   1.000000           NaN
# Current_year                            NaN        NaN           NaN
# Number of years                   -0.413922   0.419688           NaN
# fuel_Diesel                        0.282947   0.285396           NaN
# fuel_Electric                     -0.005095  -0.001372           NaN
# fuel_LPG                          -0.042434   0.036652           NaN
# fuel_Petrol                       -0.269453  -0.291139           NaN
# seller_type_Individual            -0.236798   0.182663           NaN
# seller_type_Trustmark Dealer       0.110176  -0.089858           NaN
# transmission_Manual               -0.530205   0.120226           NaN
# owner_Fourth & Above Owner        -0.078725   0.097349           NaN
# owner_Second Owner                -0.161986   0.195203           NaN
# owner_Test Drive Car               0.048799  -0.083445           NaN
# owner_Third Owner                 -0.111326   0.194713           NaN
#
#                               Number of years  fuel_Diesel  fuel_Electric  \
# selling_price                       -0.413922     0.282947      -0.005095
# km_driven                            0.419688     0.285396      -0.001372
# Current_year                              NaN          NaN            NaN
# Number of years                      1.000000    -0.121424       0.025540
# fuel_Diesel                         -0.121424     1.000000      -0.015063
# fuel_Electric                        0.025540    -0.015063       1.000000
# fuel_LPG                             0.051266    -0.072422      -0.001108
# fuel_Petrol                          0.114908    -0.970934      -0.014856
# seller_type_Individual               0.173703    -0.035314      -0.026118
# seller_type_Trustmark Dealer        -0.100225    -0.007911      -0.002355
# transmission_Manual                  0.143800    -0.048098      -0.044746
# owner_Fourth & Above Owner           0.186361    -0.021054      -0.002094
# owner_Second Owner                   0.292349     0.003524       0.025960
# owner_Test Drive Car                -0.095795    -0.010575      -0.000952
# owner_Third Owner                    0.244308     0.009373      -0.004166
#
#                               fuel_LPG  fuel_Petrol  seller_type_Individual  \
# selling_price                -0.042434    -0.269453               -0.236798
# km_driven                     0.036652    -0.291139                0.182663
# Current_year                       NaN          NaN                     NaN
# Number of years               0.051266     0.114908                0.173703
# fuel_Diesel                  -0.072422    -0.970934               -0.035314
# fuel_Electric                -0.001108    -0.014856               -0.026118
# fuel_LPG                      1.000000    -0.071427                0.035122
# fuel_Petrol                  -0.071427     1.000000                0.029845
# seller_type_Individual        0.035122     0.029845                1.000000
# seller_type_Trustmark Dealer -0.011324     0.012489               -0.266904
# transmission_Manual           0.024764     0.039614                0.214163
# owner_Fourth & Above Owner    0.013384     0.011502                0.072322
# owner_Second Owner            0.030141    -0.012717                0.186573
# owner_Test Drive Car         -0.004577     0.012427               -0.107886
# owner_Third Owner             0.004836    -0.008502                0.140823
#
#                               seller_type_Trustmark Dealer  \
# selling_price                                     0.110176
# km_driven                                        -0.089858
# Current_year                                           NaN
# Number of years                                  -0.100225
# fuel_Diesel                                      -0.007911
# fuel_Electric                                    -0.002355
# fuel_LPG                                         -0.011324
# fuel_Petrol                                       0.012489
# seller_type_Individual                           -0.266904
# seller_type_Trustmark Dealer                      1.000000
# transmission_Manual                              -0.042346
# owner_Fourth & Above Owner                       -0.021395
# owner_Second Owner                               -0.076764
# owner_Test Drive Car                             -0.009729
# owner_Third Owner                                -0.042578
#
#                               transmission_Manual  owner_Fourth & Above Owner  \
# selling_price                           -0.530205                   -0.078725
# km_driven                                0.120226                    0.097349
# Current_year                                  NaN                         NaN
# Number of years                          0.143800                    0.186361
# fuel_Diesel                             -0.048098                   -0.021054
# fuel_Electric                           -0.044746                   -0.002094
# fuel_LPG                                 0.024764                    0.013384
# fuel_Petrol                              0.039614                    0.011502
# seller_type_Individual                   0.214163                    0.072322
# seller_type_Trustmark Dealer            -0.042346                   -0.021395
# transmission_Manual                      1.000000                    0.035597
# owner_Fourth & Above Owner               0.035597                    1.000000
# owner_Second Owner                       0.068068                   -0.080648
# owner_Test Drive Car                     0.009152                   -0.008648
# owner_Third Owner                        0.030802                   -0.037849
#
#                               owner_Second Owner  owner_Test Drive Car  \
# selling_price                          -0.161986              0.048799
# km_driven                               0.195203             -0.083445
# Current_year                                 NaN                   NaN
# Number of years                         0.292349             -0.095795
# fuel_Diesel                             0.003524             -0.010575
# fuel_Electric                           0.025960             -0.000952
# fuel_LPG                                0.030141             -0.004577
# fuel_Petrol                            -0.012717              0.012427
# seller_type_Individual                  0.186573             -0.107886
# seller_type_Trustmark Dealer           -0.076764             -0.009729
# transmission_Manual                     0.068068              0.009152
# owner_Fourth & Above Owner             -0.080648             -0.008648
# owner_Second Owner                      1.000000             -0.036672
# owner_Test Drive Car                   -0.036672              1.000000
# owner_Third Owner                      -0.160498             -0.017210
#
#                               owner_Third Owner
# selling_price                         -0.111326
# km_driven                              0.194713
# Current_year                                NaN
# Number of years                        0.244308
# fuel_Diesel                            0.009373
# fuel_Electric                         -0.004166
# fuel_LPG                               0.004836
# fuel_Petrol                           -0.008502
# seller_type_Individual                 0.140823
# seller_type_Trustmark Dealer          -0.042578
# transmission_Manual                    0.030802
# owner_Fourth & Above Owner            -0.037849
# owner_Second Owner                    -0.160498
# owner_Test Drive Car                  -0.017210
# owner_Third Owner                      1.000000

# %%
import seaborn as sns

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\karti\appdata\roaming\python\python310\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\karti\appdata\roaming\python\python310\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\karti\appdata\roaming\python\python310\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\karti\appdata\roaming\python\python310\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\karti\appdata\roaming\python\python310\site-packages (from seaborn) (1.9.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\karti\appdata\roaming\python\python310\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\karti\appdata\roaming\python\python310\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\karti\appdata\roaming\python\python310\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\karti\appdata\roaming\python\python310\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karti\appdata\roaming\python\python310\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karti\appdata\roaming\python\python310\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\karti\appdata\roaming\python\python310\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karti\appdata\roaming\python\python310\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\karti\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %%
sns.pairplot(final_dataset)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corrmat=final_dataset.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))

#plot heat map 
g=sns.heatmap(final_dataset[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
final_dataset.head()
# Out:
#    selling_price  km_driven  Current_year  Number of years  fuel_Diesel  \
# 0          60000      70000          2022               15            0
# 1         135000      50000          2022               15            0
# 2         600000     100000          2022               10            1
# 3         250000      46000          2022                5            0
# 4         450000     141000          2022                8            1
#
#    fuel_Electric  fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0              0         0            1                       1
# 1              0         0            1                       1
# 2              0         0            0                       1
# 3              0         0            1                       1
# 4              0         0            0                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  \
# 0                             0                    1
# 1                             0                    1
# 2                             0                    1
# 3                             0                    1
# 4                             0                    1
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                           0                   0                     0
# 1                           0                   0                     0
# 2                           0                   0                     0
# 3                           0                   0                     0
# 4                           0                   1                     0
#
#    owner_Third Owner
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
###independent (x) and dependent(y) features
x= final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
x.head()
# Out:
#    km_driven  Current_year  Number of years  fuel_Diesel  fuel_Electric  \
# 0      70000          2022               15            0              0
# 1      50000          2022               15            0              0
# 2     100000          2022               10            1              0
# 3      46000          2022                5            0              0
# 4     141000          2022                8            1              0
#
#    fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0         0            1                       1
# 1         0            1                       1
# 2         0            0                       1
# 3         0            1                       1
# 4         0            0                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  \
# 0                             0                    1
# 1                             0                    1
# 2                             0                    1
# 3                             0                    1
# 4                             0                    1
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                           0                   0                     0
# 1                           0                   0                     0
# 2                           0                   0                     0
# 3                           0                   0                     0
# 4                           0                   1                     0
#
#    owner_Third Owner
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
y.head()
# Out:
# 0     60000
# 1    135000
# 2    600000
# 3    250000
# 4    450000
# Name: selling_price, dtype: int64

# %%
###Feature Importance
from sklearn.ensemble import ExtraTreesRegressor
model= ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [2.41541100e-01 0.00000000e+00 2.51513922e-01 1.30108503e-01
#  3.96777292e-05 2.45713269e-05 2.49985045e-04 4.67150570e-02
#  8.10754623e-03 2.92836096e-01 7.45532767e-04 2.23949331e-02
#  7.43838046e-04 4.97923808e-03]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(5).plot(kind='barh') 
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.head()
# Out:
#       km_driven  Current_year  Number of years  fuel_Diesel  fuel_Electric  \
# 658       80000          2022               10            1              0
# 3415      20000          2022               11            0              0
# 2578      53000          2022                9            1              0
# 2240      52600          2022                6            1              0
# 3083     120000          2022               10            1              0
#
#       fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 658          0            0                       1
# 3415         0            1                       1
# 2578         0            0                       0
# 2240         0            0                       1
# 3083         0            0                       1
#
#       seller_type_Trustmark Dealer  transmission_Manual  \
# 658                              0                    1
# 3415                             0                    1
# 2578                             0                    0
# 2240                             0                    1
# 3083                             0                    0
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 658                            0                   0                     0
# 3415                           0                   0                     0
# 2578                           0                   0                     0
# 2240                           0                   0                     0
# 3083                           0                   0                     0
#
#       owner_Third Owner
# 658                   0
# 3415                  0
# 2578                  0
# 2240                  0
# 3083                  1

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random=RandomForestRegressor()

# %%
####Hyperparameters tuning
n_estimators=[int(x)]
